# %%
class MerkleTreeNode:
    def __init__(self, left, right, value,content):
        self.left = left
        self.right = right
        self.value = value
        self.content = content
    def hash(val):
        return hashlib.sha256(val.encode("utf-8")).hexdigest()
    def __str__(self):
        return(str(self.value))

# %%
        
class MerkleTree:
    def __init__(self, values):
        self.buildTree(values)
    
    def buildTree(self, leaves):
        leaves = [MerkleTreeNode(None, None, MerkleTreeNode.hash(e),e) for e in leaves]
        while len(leaves) > 1:
            length = len(leaves)
            for i in range(length//2):
                left = leaves.pop(0)
                right = leaves.pop(0)
                value: str = MerkleTreeNode.hash(left.value + right.value)
                print('value:  ',value)
                content: str = left.content + '+'+ right.content
                leaves.append(MerkleTreeNode(left, right, MerkleTreeNode.hash(value),content))
            if length%2 == 1:
                leaves.append(leaves.pop(0))
            print('leaves')
            print(leaves)
            print()
        self.root = leaves[0]
        
    def printTree(self, node)-> None:
        if node != None:
            if node.left != None:
                print("Left: "+str(node.left))
                print("Right: "+str(node.right))
            else:
                print("Input")
            print("Value: "+str(node.value))
            print("Content: "+str(node.content))
            print("")
            self.printTree(node.left)
            self.printTree(node.right)
    
    def getRootHash(self)-> str:
         return self.root.value

# %% [markdown]
# **['1', '2', '3', '4']四个值**

# %%
elems = ['1', '2', '3', '4']
print('构造树')
mtree = MerkleTree(elems)
print('打印根哈希值')
print("Root Hash: "+mtree.getRootHash()+"\n")
print('打印默克尔树')
mtree.printTree(mtree.root)
# Out:
# 构造树
# value:   33b675636da5dcc86ec847b38c08fa49ff1cace9749931e0a5d4dfdbdedd808a
# value:   13656c83d841ea7de6ebf3a89e0038fea9526bd7f686f06f7a692343a8a32dca
# leaves
# [<__main__.MerkleTreeNode object at 0x00000262B91069D0>, <__main__.MerkleTreeNode object at 0x00000262B91067F0>]
#
# value:   54fbc0573735c3274d7c5c0f1284059bac46b922a5cfc0db9d1d869e0afe5646
# leaves
# [<__main__.MerkleTreeNode object at 0x00000262B9106430>]
#
# 打印根哈希值
# Root Hash: 42c7b64022982d378bcb34b419adf5353c9076ca9bd9ce972d93c65933966b60
#
# 打印默克尔树
# Left: bf1888a95f2ee8bf7130de1157f640b6428312474dcfa71ebfd336bb2292bab8
# Right: 01470d6b5c228b29a64efbf2ace5e4c17deda8409d53fcf55cebc056e7c7c775
# Value: 42c7b64022982d378bcb34b419adf5353c9076ca9bd9ce972d93c65933966b60
# Content: 1+2+3+4
#
# Left: 6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d49c01e52ddb7875b4b
# Right: d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f90da3a666eec13ab35
# Value: bf1888a95f2ee8bf7130de1157f640b6428312474dcfa71ebfd336bb2292bab8
# Content: 1+2
#
# Input
# Value: 6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d49c01e52ddb7875b4b
# Content: 1
#
# Input
# Value: d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f90da3a666eec13ab35
# Content: 2
#
# Left: 4e07408562bedb8b60ce05c1decfe3ad16b72230967de01f640b7e4729b49fce
# Right: 4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328cb08b5531fcacdabf8a
# Value: 01470d6b5c228b29a64efbf2ace5e4c17deda8409d53fcf55cebc056e7c7c775
# Content: 3+4
#
# Input
# Value: 4e07408562bedb8b60ce05c1decfe3ad16b72230967de01f640b7e4729b49fce
# Content: 3
#
# Input
# Value: 4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328cb08b5531fcacdabf8a
# Content: 4

# %% [markdown]
# **['1', '2', '3', '4', '5', '6', '7','8', '9']九个值**

# %%
elems = ['1', '2', '3', '4', '5', '6', '7','8', '9']
print('构造树')
mtree = MerkleTree(elems)
print('打印根哈希值')
print("Root Hash: "+mtree.getRootHash()+"\n")
print('打印默克尔树')
mtree.printTree(mtree.root)
# Out:
# 构造树
# value:   33b675636da5dcc86ec847b38c08fa49ff1cace9749931e0a5d4dfdbdedd808a
# value:   13656c83d841ea7de6ebf3a89e0038fea9526bd7f686f06f7a692343a8a32dca
# value:   43587f59c00a8e528bc7636fabaffcf70cc25afc5b4d53df797faf0dc72f6dd0
# value:   ada17dcc2d615cc0d982a538b618f45441e798c38b1df9f3dd273e386eba1363
# leaves
# [<__main__.MerkleTreeNode object at 0x00000262B8FE49A0>, <__main__.MerkleTreeNode object at 0x00000262B8FE4E20>, <__main__.MerkleTreeNode object at 0x00000262B8FE4790>, <__main__.MerkleTreeNode object at 0x00000262B8FEF0A0>, <__main__.MerkleTreeNode object at 0x00000262B8FFE430>]
#
# value:   54fbc0573735c3274d7c5c0f1284059bac46b922a5cfc0db9d1d869e0afe5646
# value:   3f515a44368254b688abc1c2341d64519d028641445a370b0424ca98de3e4909
# leaves
# [<__main__.MerkleTreeNode object at 0x00000262B903C940>, <__main__.MerkleTreeNode object at 0x00000262B903C9D0>, <__main__.MerkleTreeNode object at 0x00000262B8FFE430>]
#
# value:   0ebb838e4e5a3a8b33ad86bdc10dd8de91df523a83bd716fed99cf274b8333af
# leaves
# [<__main__.MerkleTreeNode object at 0x00000262B903CDC0>, <__main__.MerkleTreeNode object at 0x00000262B8FFE430>]
#
# value:   3d4011610fb3faf843d30676d66af66c7ed17f5d361fda4c0375a4eb80b6cc8f
# leaves
# [<__main__.MerkleTreeNode object at 0x00000262B903C340>]
#
# 打印根哈希值
# Root Hash: a798e697c131a35cf335b3d3b962c448796461900ce3363f5ff586482adcf8d0
#
# 打印默克尔树
# Left: 41da10f32fb17c82174960da1f9c1565bafb1c35334df964a4e23788dfbbaade
# Right: 19581e27de7ced00ff1ce50b2047e7a567c76b1cbaebabe5ef03f7c3017bb5b7
# Value: a798e697c131a35cf335b3d3b962c448796461900ce3363f5ff586482adcf8d0
# Content: 1+2+3+4+5+6+7+8+9
#
# Left: 42c7b64022982d378bcb34b419adf5353c9076ca9bd9ce972d93c65933966b60
# Right: 7dcd399aea085372ac103dbd38a47bd92a95e42def37113d55f01e3cadbfa7c2
# Value: 41da10f32fb17c82174960da1f9c1565bafb1c35334df964a4e23788dfbbaade
# Content: 1+2+3+4+5+6+7+8
#
# Left: bf1888a95f2ee8bf7130de1157f640b6428312474dcfa71ebfd336bb2292bab8
# Right: 01470d6b5c228b29a64efbf2ace5e4c17deda8409d53fcf55cebc056e7c7c775
# Value: 42c7b64022982d378bcb34b419adf5353c9076ca9bd9ce972d93c65933966b60
# Content: 1+2+3+4
#
# Left: 6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d49c01e52ddb7875b4b
# Right: d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f90da3a666eec13ab35
# Value: bf1888a95f2ee8bf7130de1157f640b6428312474dcfa71ebfd336bb2292bab8
# Content: 1+2
#
# Input
# Value: 6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d49c01e52ddb7875b4b
# Content: 1
#
# Input
# Value: d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f90da3a666eec13ab35
# Content: 2
#
# Left: 4e07408562bedb8b60ce05c1decfe3ad16b72230967de01f640b7e4729b49fce
# Right: 4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328cb08b5531fcacdabf8a
# Value: 01470d6b5c228b29a64efbf2ace5e4c17deda8409d53fcf55cebc056e7c7c775
# Content: 3+4
#
# Input
# Value: 4e07408562bedb8b60ce05c1decfe3ad16b72230967de01f640b7e4729b49fce
# Content: 3
#
# Input
# Value: 4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328cb08b5531fcacdabf8a
# Content: 4
#
# Left: a0a721cdb770ca64c698e819c0e2f0f21338289317ca9eb097f7220c1f763ca9
# Right: d4f247cd06bd7c1ab0ad3b95076372f01d1413036ec21568cb9033c4e3ee2fc7
# Value: 7dcd399aea085372ac103dbd38a47bd92a95e42def37113d55f01e3cadbfa7c2
# Content: 5+6+7+8
#
# Left: ef2d127de37b942baad06145e54b0c619a1f22327b2ebbcfbec78f5564afe39d
# Right: e7f6c011776e8db7cd330b54174fd76f7d0216b612387a5ffcfb81e6f0919683
# Value: a0a721cdb770ca64c698e819c0e2f0f21338289317ca9eb097f7220c1f763ca9
# Content: 5+6
#
# Input
# Value: ef2d127de37b942baad06145e54b0c619a1f22327b2ebbcfbec78f5564afe39d
# Content: 5
#
# Input
# Value: e7f6c011776e8db7cd330b54174fd76f7d0216b612387a5ffcfb81e6f0919683
# Content: 6
#
# Left: 7902699be42c8a8e46fbbb4501726517e86b22c56a189f7625a6da49081b2451
# Right: 2c624232cdd221771294dfbb310aca000a0df6ac8b66b696d90ef06fdefb64a3
# Value: d4f247cd06bd7c1ab0ad3b95076372f01d1413036ec21568cb9033c4e3ee2fc7
# Content: 7+8
#
# Input
# Value: 7902699be42c8a8e46fbbb4501726517e86b22c56a189f7625a6da49081b2451
# Content: 7
#
# Input
# Value: 2c624232cdd221771294dfbb310aca000a0df6ac8b66b696d90ef06fdefb64a3
# Content: 8
#
# Input
# Value: 19581e27de7ced00ff1ce50b2047e7a567c76b1cbaebabe5ef03f7c3017bb5b7
# Content: 9
